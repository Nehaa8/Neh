# %% [markdown]
# Importing needed python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading and printing data

# %%
data = pd.read_csv(r'C:\Users\Raj\Downloads\SP.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Knowing size of data

# %%
print (df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a743c05d7a7> in <module>
# ----> 1 print (df.shape)
#
# NameError: name 'df' is not defined

# %%
print (data.shape)
# Out:
# (1000, 8)

# %% [markdown]
# checking if data has missing values or not

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# checking data types of every column value

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# examining column values and checking if it falls under categorical or numerical.

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# hence the top values are categorical and the marks always fall under numerical

# %% [markdown]
# creating total and average columns and adding to data set

# %%
data['total'] = data['math score'] + data['reading score'] + data['writing score']
data['average'] = data['total'] / 3

# %% [markdown]
# checking distribution of scores

# %%
sns.distplot(data['math score'])

# %%
sns.distplot(data['reading score'])

# %%
sns.distplot(data['writing score'])

# %%
sns.distplot(data['average'])

# %%
sns.pairplot(data)

# %% [markdown]
# analysing average score of all based on race,parental level of edu,test prep

# %%
sns.barplot(data['race/ethnicity'], data['average'])

# %%
sns.barplot(data['parental level of education'], data['average'])

# %%
sns.barplot(data['test preparation course'], data['average'])

# %% [markdown]
# analysing based on if they are passed or failed(pass>40 marks)

# %%
data['math_PassStatus'] = np.where(data['math score']<40, 'F', 'P')
data['read_PassStatus'] = np.where(data['reading score']<40, 'F', 'P')
data['write_PassStatus'] = np.where(data['writing score']<40, 'F', 'P')

# %%
data['math_PassStatus'].value_counts()
# Out:
# P    960
# F     40
# Name: math_PassStatus, dtype: int64

# %%
data['read_PassStatus'].value_counts()
# Out:
# P    974
# F     26
# Name: read_PassStatus, dtype: int64

# %%
data['write_PassStatus'].value_counts()
# Out:
# P    968
# F     32
# Name: write_PassStatus, dtype: int64

# %%
 p = sns.countplot(x='parental level of education', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='parental level of education', data = data, hue='read_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data = data, hue='read_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='parental level of education', data = data, hue='write_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data = data, hue='write_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
 p = sns.countplot(x='gender', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='race/ethnicity', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='lunch', data = data, hue='math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
Under math scores, 960 students passed and 40 failed
Under reading scores, 970 students have passed and 26 failed
Under writing scores, 968 students have passed and 32 failed
As we see above 
It is evident that 
-Group E has higher average score(70 approx) than other groups.
-Students whose parents having masters or bachelors degree have higher average score(70 approx)
-Students who completed test preparation have the most average score(70 approx)
-Approximately 200 plus students passed whose parents have associate or some college degree
-Approximately 600 plus students passed who come under none test preparation course 
-Females have passed out more than males
-Group C students are higher in number in passing followed by group D
-600 students approximately have passed having standard lunch

Hence we understood how the students performance is affected due to various gievn factors.
